# %%
import sys
sys.path.append('../src')

# %%
# %load_ext autoreload
# %autoreload 2
from src.universe import get_scoped_universe
from src.scrape_technews import fetch_archive_page, parse_article_listing

# %%
html = fetch_archive_page("semiconductor", 1)

# %%
results = parse_article_listing(html)
len(results)
# Out:
# 15

# %%
print(len(html))
print(html[:500])
# Out:
# 162913
# <!DOCTYPE html>
# <!--[if IE 7]>
# <html class="ie ie7" lang="zh-TW">
# <![endif]-->
# <!--[if IE 8]>
# <html class="ie ie8" lang="zh-TW">
# <![endif]-->
# <!--[if !(IE 7) | !(IE 8)  ]><!-->
# <html lang="zh-TW">
# <!--<![endif]-->
# <head>
# 	<script>
#         window.aiQAEligible = ;
#         window.isSponsored = ;
#         window.abVariant = null;
#         console.log('AI QA Eligible:', window.aiQAEligible);
#         console.log('Is Sponsored Content:', window.isSponsored);
#                     console.log('AB Test Disab

# %%
results[0]
# Out:
# {'title': '中國 DUV 交付消息引發半導體連鎖殺盤效應，專家解析真相指劃錯重點',
#  'url': 'https://finance.technews.tw/2026/07/28/news-of-chinas-duv-delivery-triggers-a-chain-reaction-in-the-semiconductor-industry/',
#  'publish_date': datetime.datetime(2026, 7, 28, 21, 50)}

# %%
results[:3]
# Out:
# [{'title': '中國 DUV 交付消息引發半導體連鎖殺盤效應，專家解析真相指劃錯重點',
#   'url': 'https://finance.technews.tw/2026/07/28/news-of-chinas-duv-delivery-triggers-a-chain-reaction-in-the-semiconductor-industry/',
#   'publish_date': datetime.datetime(2026, 7, 28, 21, 50)},
#  {'title': '終結沃爾瑪 12 年霸權！亞馬遜登頂《財富》500 強，貝佐斯揭成長關鍵：AI 與晶片布局',
#   'url': 'https://finance.technews.tw/2026/07/28/amazons-jeff-bezos-on-how-his-garage-startup-became-the-largest-company-in-the-world-by-revenue/',
#   'publish_date': datetime.datetime(2026, 7, 28, 17, 50)},
#  {'title': '強茂發布永續報告書，深化 ESG 治理、擴大能源管理',
#   'url': 'https://technews.tw/2026/07/28/panjit-sustainability-report-esg-governance-green-power-expansion/',
#   'publish_date': datetime.datetime(2026, 7, 28, 17, 24)}]

# %%
# %load_ext autoreload
# %autoreload 2
from src.scrape_technews import fetch_full_article

# %%
test_url = results[0]['url']
article_text = fetch_full_article(test_url)
print(len(article_text))
print(article_text[:300])
# Out:
# 1208
# 日前，一篇出自外媒The Information最新報導，指出一家未具名的中國國家支持企業已成功製造國產DUV（深紫外光）微影曝光設備，並預計於近期交付5台，2027年計畫交付20台。此消息一出，立刻引發市場對全球微影設備龍頭ASML（艾司摩爾）競爭前景的擔憂，甚至被部分人士認為是近期ASML股價下跌的導火線。然而，綜合產業鏈實際運作邏輯與市場數據分析，這項競爭消息引發的恐慌似乎被過度放大。
#
# 首先，市場人士針對「交付」的真實涵義提出了與外界不同的解讀。在半導體產業中，設備的「銷售」與「交付」並不等同於能夠立刻在晶圓廠的產線上進行大規模量產。回顧2023年，中國SMEE曾交付6台DUV乾式微影

# %%
# %load_ext autoreload
# %autoreload 2
from src.scrape_technews import matches_ticker
from src.universe import get_scoped_universe
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
matches_ticker(article_text, get_scoped_universe())
# Out:
# ['2330.TW']

# %%
# %load_ext autoreload
# %autoreload 2
from src.scrape_technews import scrape_category
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from datetime import datetime, timedelta

test_start = datetime.now() - timedelta(days=3)
test_end = datetime.now()

results = scrape_category("semiconductor", get_scoped_universe(), test_start, test_end,
                           checkpoint_path="../data/raw_articles/_test_checkpoint.csv")
# Out:
# [semiconductor] page 1: 15 listings, 0 matches so far
# [semiconductor] page 1: 15 listings, date range on this page: 2026-07-30 13:48:00 to 2026-07-31 07:00:00, 5 matches so far
# [semiconductor] page 2: 15 listings, 5 matches so far
# [semiconductor] page 2: 15 listings, date range on this page: 2026-07-30 08:23:00 to 2026-07-30 12:20:00, 15 matches so far
# [semiconductor] page 3: 15 listings, 15 matches so far
# [semiconductor] page 3: 15 listings, date range on this page: 2026-07-29 14:36:00 to 2026-07-30 08:00:00, 26 matches so far
# [semiconductor] page 4: 15 listings, 26 matches so far
# [semiconductor] page 4: 15 listings, date range on this page: 2026-07-29 08:30:00 to 2026-07-29 14:10:00, 33 matches so far
# [semiconductor] page 5: 15 listings, 33 matches so far
# [semiconductor] page 5: 15 listings, date range on this page: 2026-07-28 15:41:00 to 2026-07-29 08:00:00, 40 matches so far
# [semiconductor] page 6: 15 listings, 40 matches so far
# ...

# %%
print(len(results))
print(results[0])
# Out:
# 57
# {'tickers': '2330.TW', 'title': '熊本地震，經長：台積電 JASM 一廠暫停生產檢查設備', 'url': 'https://technews.tw/2026/07/30/kumamoto-earthquake-tsmc-jasm-fab-1-production-suspended-equipment-inspection/', 'publish_date': datetime.datetime(2026, 7, 30, 18, 20), 'text': '日本熊本 28 日發生強震，經濟部長龔明鑫今天表示，台積電熊本 JASM 二廠仍在興建，地震後已復工，一廠則因已投入量產，目前暫停並進行設備檢查，盼儘快復工；除半導體產業外，熊本台廠整體營運及人員狀況大致正常。\n龔明鑫今天主持業務會報前受訪表示，經濟部在地震發生第一時間即透過駐外單位了解當地台廠情況，目前除半導體產業外，其餘台廠人員及營運狀況大致正常。\n至於外界關注台積電熊本JASM晶圓廠情形，龔明鑫表示，JASM分為兩座廠區，二廠仍在興建，地震後確認沒有問題，已復工，而一廠因開始量產，地震發生後暫停檢查，希望能儘快復工。\n日本熊本縣28日下午發生規模7.1地震，台積電指出，JASM人員及廠區建築結構皆安全無虞，廠區供水、電力及工安系統運作正常，由於這次震幅較大，預計需要一定的時間調整校正，經盤點後，台積電已調派資源支援JASM，目前原物料供應無虞。\n市場分析，半導體設備對振動極為敏感，地震除了可能造成製程中晶圓報廢，也可能導致相關製程參數偏離規格，產線須在完成建築檢查後重新確認製程參數。\n不過，JASM第一座晶圓廠規劃月產能為5.5萬片12吋晶圓，涵蓋28、22、16、12奈米製程，產品主要用於Sony的影像感測器（CIS）、邏輯晶片、車用電子及工業應用。不過在車用與智慧手機需求疲軟下，實際月產能約2萬片，仍處於產能爬坡階段，估計對台積電第三季營收影響應有限。\n（作者：曾筠庭；首圖來源：台積電）'}

# %%
print([r["tickers"] for r in results])
print([r["publish_date"] for r in results])
# Out:
# ['2330.TW', '2330.TW', '2330.TW', '2382.TW', '3711.TW', '6488.TWO', '2303.TW', '2330.TW', '2382.TW', '3231.TW', '4938.TW', '2317.TW', '3036.TW', '2330.TW', '2330.TW', '2330.TW', '2303.TW', '2303.TW', '2330.TW', '2303.TW', '3037.TW', '2408.TW', '2337.TW', '2327.TW', '3037.TW', '8046.TW', '2330.TW', '2330.TW', '6239.TW', '2330.TW', '2308.TW', '2395.TW', '2330.TW', '2330.TW', '2337.TW', '2330.TW', '2408.TW', '2344.TW', '2330.TW', '6239.TW', '2330.TW', '6239.TW', '3481.TW', '2408.TW', '2344.TW', '8299.TWO', '2337.TW', '2330.TW', '3231.TW', '2317.TW', '2330.TW', '2454.TW', '2408.TW', '2344.TW', '2337.TW', '2330.TW', '2317.TW']
# ...

# %%
html = fetch_archive_page("semiconductor", 2)
print(len(html))
print(html[:300])
# Out:
# 162183
# <!DOCTYPE html>
# <!--[if IE 7]>
# <html class="ie ie7" lang="zh-TW">
# <![endif]-->
# <!--[if IE 8]>
# <html class="ie ie8" lang="zh-TW">
# <![endif]-->
# <!--[if !(IE 7) | !(IE 8)  ]><!-->
# <html lang="zh-TW">
# <!--<![endif]-->
# <head>
# 	<script>
#         window.aiQAEligible = ;
#         window.isSponsored = ;

# %%
import pandas as pd
df = pd.read_csv("../data/raw_articles/metadata_index.csv")

print(df.shape)
print(df['publish_date'].min(), df['publish_date'].max())
print(df['tickers'].value_counts())
# Out:
# (2184, 5)
# 2025-07-01 08:50:00 2026-06-29 15:48:00
# tickers
# 2330.TW     1135
# 2454.TW      166
# 2317.TW      116
# 2303.TW       65
# 6770.TW       65
# 2357.TW       54
# 6239.TW       52
# 2344.TW       47
# 2408.TW       44
# 2337.TW       40
# 3443.TW       38
# 3711.TW       35
# 8299.TWO      34
# 6488.TWO      27
# 2308.TW       22
# 6515.TW       20
# 3481.TW       19
# 2382.TW       17
# 2376.TW       16
# 4938.TW       14
# 3081.TWO      11
# 2395.TW       10
# 3665.TW       10
# 3008.TW       10
# 2327.TW        8
# 3231.TW        8
# 2356.TW        8
# 2449.TW        7
# 5274.TWO       7
# 2379.TW        6
# 2345.TW        6
# 2360.TW        6
# 3037.TW        6
# 3653.TW        6
# 3105.TWO       6
# 8069.TWO       6
# 3017.TW        5
# 3661.TW        5
# 2383.TW        4
# 8046.TW        4
# 3036.TW        4
# 2404.TW        3
# 6223.TWO       2
# 6139.TW        2
# 3034.TW        2
# 6415.TW        1
# 2492.TW        1
# 6274.TWO       1
# 2301.TW        1
# ...

# %%
df.sample(5)
# Out:
#                                   filename  tickers  \
# 1026  6255caa65999a036f1fe2cbcc6d33a3c.txt  2330.TW
# 1568  26104a2ffa8b52396a9fdfb6cf5e7c76.txt  2376.TW
# 653   e923a38743ec3417115ad262ac1f2085.txt  2330.TW
# 409   3342273b18a53bec9759ac90335a4f6e.txt  2330.TW
# 515   5ec2739de51ca27716aca7829884b1a3.txt  2303.TW
#
#                                   title  \
# 1026             三星將關閉一座 8 吋廠，資源重押高利潤製程
# 1568  清華與技鋼產學大協作！再獲 ISC 2025 歐洲超級電腦大賽亞軍
# 653         博通示警：台積電產能逼近極限，三到五年長約成為業界趨勢
# 409    首季每股賺 1.18 元！世界先進估 Q2 毛利率將重返三成以上
# 515               成熟製程漲定了！聯電下半年開始調漲晶圓價格
#
#                                                     url         publish_date
# 1026  https://technews.tw/2026/01/15/samsung-to-clos...  2026-01-15 10:10:00
# 1568  https://technews.tw/2025/10/15/gigacomputing-s...  2025-10-15 13:00:00
# 653   https://technews.tw/2026/03/25/broadcom-warns-...  2026-03-25 07:30:00
# 409   https://finance.technews.tw/2026/05/05/vis-202...  2026-05-05 15:28:00
# ...

# %%
import pandas as pd
df = pd.read_csv("../data/raw_articles/metadata_index.csv")
print(df.shape)
print(df['publish_date'].min(), df['publish_date'].max())
# Out:
# (2706, 5)
# 2025-07-01 08:15:00 2026-06-29 15:48:00

# %%
df['tickers'].value_counts().head(10)
# Out:
# tickers
# 2330.TW    1163
# 2317.TW     209
# 2454.TW     171
# 2357.TW      94
# 6239.TW      75
# 2303.TW      67
# 6770.TW      66
# 2308.TW      53
# 2344.TW      47
# 3443.TW      45
# Name: count, dtype: int64
